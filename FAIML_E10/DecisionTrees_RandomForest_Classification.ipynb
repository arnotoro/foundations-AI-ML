# %% [markdown]
# # Random Forest applied to LendingClub data set
#
# For this exercise, we will be exploring publicly available data from [LendingClub.com](www.lendingclub.com). Lending Club connects people who need money (borrowers) with people who have money (investors). We try to create a model to predict the risk of lending money to someone given a wide range of credit related data. We will use lending data from 2007-2010 and be trying to classify and predict **whether or not the borrower paid back their loan in full.**
#
# Here are what the columns in the data set represent:
#
# * **credit.policy**: 1 if the customer meets the credit underwriting criteria of LendingClub.com, and 0 otherwise.
# * **purpose**: The purpose of the loan (takes values "credit_card", "debt_consolidation", "educational", "major_purchase", "small_business", and "all_other").
# * **int.rate**: The interest rate of the loan, as a proportion (a rate of 11% would be stored as 0.11). Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# * **installment**: The monthly installments owed by the borrower if the loan is funded.
# * **log.annual.inc**: The natural log of the self-reported annual income of the borrower.
# * **dti**: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# * **fico**: The FICO credit score of the borrower.
# * **days.with.cr.line**: The number of days the borrower has had a credit line.
# * **revol.bal**: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# * **revol.util**: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# * **inq.last.6mths**: The borrower's number of inquiries by creditors in the last 6 months.
# * **delinq.2yrs**: The number of times the borrower had been 30+ days past due on a payment in the past 2 years.
# * **pub.rec**: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).
# * **not.fully.paid**: The quantity of interest for classification - whether the borrower paid back the money in full or not

# %% [markdown]
# # Import Libraries and data set
#
# **Import the usual libraries for pandas and plotting**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Get the Data
#
# ** Use pandas to read loan_data.csv**

# %%
df = pd.read_csv('loan_data.csv')

# %% [markdown]
# ### Check out the info(), head(), and describe() methods on loans

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# min     612.000000         178.958333  0.000000e+00     0.000000
# 25%     682.000000        2820.000000  3.187000e+03    22.600000
# 50%     707.000000        4139.958333  8.596000e+03    46.300000
# 75%     737.000000        5730.000000  1.824950e+04    70.900000
# max     827.000000       17639.958330  1.207359e+06   119.000000
#
#        inq.last.6mths  delinq.2yrs      pub.rec  not.fully.paid
# count     9578.000000  9578.000000  9578.000000     9578.000000
# mean         1.577469     0.163708     0.062122        0.160054
# std          2.200245     0.546215     0.262126        0.366676
# min          0.000000     0.000000     0.000000        0.000000
# 25%          0.000000     0.000000     0.000000        0.000000
# 50%          1.000000     0.000000     0.000000        0.000000
# 75%          2.000000     0.000000     0.000000        0.000000
# max         33.000000    13.000000     5.000000        1.000000

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0
# 3            0        0               0
# 4            1        0               0

# %%
print("Follwoing is a breakup of credit approval status. 1 means approved credit, 0 means not approved.")
print(df['credit.policy'].value_counts())
# Out:
# Follwoing is a breakup of credit approval status. 1 means approved credit, 0 means not approved.
# credit.policy
# 1    7710
# 0    1868
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Histogram of FICO scores by credit approval status

# %%
df[df['credit.policy']==1]['fico'].plot.hist(bins=30,alpha=0.5,color='blue', label='Credit.Policy=1')
df[df['credit.policy']==0]['fico'].plot.hist(bins=30,alpha=0.5, color='red', label='Credit.Policy=0')
plt.legend(fontsize=15)
plt.title ("Histogram of FICO score by approved or disapproved credit policies", fontsize=16)
plt.xlabel("FICO score", fontsize=14)
# Out:
# Text(0.5, 0, 'FICO score')

# %% [markdown]
# ### Presence or absence of statistical difference of various factors between credit approval status

# %%
sns.boxplot(x=df['credit.policy'],y=df['int.rate'])
plt.title("Interest rate varies between risky and non-risky borrowers", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Interest rate",fontsize=15)
# Out:
# Text(0, 0.5, 'Interest rate')

# %%
sns.boxplot(x=df['credit.policy'],y=df['log.annual.inc'])
plt.title("Income level does not make a big difference in credit approval odds", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Log. annual income",fontsize=15)
# Out:
# Text(0, 0.5, 'Log. annual income')

# %%
sns.boxplot(x=df['credit.policy'],y=df['days.with.cr.line'])
plt.title("Credit-approved users have a slightly higher days with credit line", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Days with credit line",fontsize=15)
# Out:
# Text(0, 0.5, 'Days with credit line')

# %%
sns.boxplot(x=df['credit.policy'],y=df['dti'])
plt.title("Debt-to-income level does not make a big difference in credit approval odds", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Debt-to-income ratio",fontsize=15)
# Out:
# Text(0, 0.5, 'Debt-to-income ratio')

# %% [markdown]
# ### Countplot of loans by purpose, with the color hue defined by not.fully.paid

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='purpose',hue='not.fully.paid',data=df, palette='Set1')
plt.title("Bar chart of loan purpose colored by not fully paid status", fontsize=17)
plt.xlabel("Purpose", fontsize=15)
# Out:
# Text(0.5, 0, 'Purpose')

# %% [markdown]
# ### Trend between FICO score and interest rate

# %%
sns.jointplot(x='fico',y='int.rate',data=df, color='purple', size=12)

# %% [markdown]
# ### lmplot to see if the trend differed between not.fully.paid and credit.policy

# %%
plt.figure(figsize=(14,7))
sns.lmplot(y='int.rate',x='fico',data=df,hue='credit.policy',
           col='not.fully.paid',palette='Set1')

# %% [markdown]
# # Setting up the Data
# ## Categorical Features
#
# The **purpose** column as categorical. We transform them using dummy variables so sklearn will be able to understand them.

# %%
df_final = pd.get_dummies(df,['purpose'],drop_first=True)

# %%
df_final.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# 0        0               0                False                        True
# 1        0               0                 True                       False
# 2        0               0                False                        True
# 3        0               0                False                        True
# 4        0               0                 True                       False
#
#    purpose_educational  purpose_home_improvement  purpose_major_purchase  \
# 0                False                     False                   False
# 1                False                     False                   False
# 2                False                     False                   False
# 3                False                     False                   False
# 4                False                     False                   False
#
#    purpose_small_business
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X = df_final.drop('not.fully.paid',axis=1)
y = df_final['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
X.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  purpose_credit_card  purpose_debt_consolidation  \
# 0        0                False                        True
# 1        0                 True                       False
# 2        0                False                        True
# 3        0                False                        True
# 4        0                 True                       False
#
#    purpose_educational  purpose_home_improvement  purpose_major_purchase  \
# 0                False                     False                   False
# 1                False                     False                   False
# 2                False                     False                   False
# 3                False                     False                   False
# 4                False                     False                   False
#
#    purpose_small_business
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9578 entries, 0 to 9577
# Series name: not.fully.paid
# Non-Null Count  Dtype
# --------------  -----
# 9578 non-null   int64
# dtypes: int64(1)
# memory usage: 75.0 KB

# %% [markdown]
# ## Training a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Create an instance of DecisionTreeClassifier() called dtree and fit it to the training data.**

# %%
dtree = DecisionTreeClassifier(criterion='gini',max_depth=None)

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree
# **Create predictions from the test set and create a classification report and a confusion matrix.**

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      2426
#            1       0.20      0.24      0.22       448
#
#     accuracy                           0.73      2874
#    macro avg       0.53      0.53      0.53      2874
# weighted avg       0.75      0.73      0.74      2874

# %%
cm=confusion_matrix(y_test,predictions)
print(cm)
print ("Accuracy of prediction:",round((cm[0,0]+cm[1,1])/cm.sum(),3))
# Out:
# [[2004  422]
#  [ 342  106]]
# Accuracy of prediction: 0.734

# %% [markdown]
# ## Training the Random Forest model
#
# Now its time to train our model!
#
# **Create an instance of the RandomForestClassifier class and fit it to our training data from the previous step.**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=600)

# %% [markdown]
# ## Predictions and Evaluation
#
# Let's predict off the y_test values and evaluate our model.
#
# **Predict the class of not.fully.paid for the X_test data.**

# %%
rfc_pred = rfc.predict(X_test)

# %% [markdown]
# **Now create a classification report from the results. Do you get anything strange or some sort of warning?**

# %%
cr = classification_report(y_test,predictions)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      2426
#            1       0.20      0.24      0.22       448
#
#     accuracy                           0.73      2874
#    macro avg       0.53      0.53      0.53      2874
# weighted avg       0.75      0.73      0.74      2874

# %% [markdown]
# **Show the Confusion Matrix for the predictions.**

# %%
cm = confusion_matrix(y_test,rfc_pred)

print(cm)
print ("Accuracy of prediction:",round((cm[0,0]+cm[1,1])/cm.sum(),3))
# Out:
# [[2420    6]
#  [ 443    5]]
# Accuracy of prediction: 0.844

# %% [markdown]
# ### Create a loop with increasing number of trees in the random forest (unlimited depth)

# %% [markdown]
# **Criterion 'gini'**

# %%
for n_tree in range(100, 2101, 400):
    rfc = RandomForestClassifier(n_estimators=n_tree, criterion='gini', max_depth=None)
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cr = classification_report(y_test,rfc_pred)
    print("Classification report with",n_tree,"trees:\n", cr)
    cm = confusion_matrix(y_test,rfc_pred)
    print("Confusion matrix with",n_tree,"trees:\n", cm)
    print ("Accuracy of prediction with",n_tree,"trees:",round((cm[0,0]+cm[1,1])/cm.sum(),3), end="\n\n")


# rfc2 = RandomForestClassifier(criterion='gini')

# rfc2.fit(X_train, y_train)
# rfc_pred2 = rfc2.predict(X_test)

# cr2 = classification_report(y_test,rfc_pred2)

# print(cr2)

# cm2 = confusion_matrix(y_test,rfc_pred2)

# print(cm2)
# print ("Accuracy of prediction:",round((cm2[0,0]+cm2[1,1])/cm2.sum(),3))
# Out:
# Classification report with 100 trees:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2426
#            1       0.56      0.02      0.04       448
#
#     accuracy                           0.84      2874
#    macro avg       0.70      0.51      0.48      2874
# weighted avg       0.80      0.84      0.78      2874
#
# Confusion matrix with 100 trees:
#  [[2419    7]
#  [ 439    9]]
# Accuracy of prediction with 100 trees: 0.845
#
# Classification report with 500 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2426
#            1       0.40      0.01      0.02       448
#
#     accuracy                           0.84      2874
#    macro avg       0.62      0.50      0.47      2874
# weighted avg       0.78      0.84      0.78      2874
#
# Confusion matrix with 500 trees:
#  [[2420    6]
#  [ 444    4]]
# Accuracy of prediction with 500 trees: 0.843
#
# Classification report with 900 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2426
#            1       0.11      0.00      0.00       448
#
#     accuracy                           0.84      2874
#    macro avg       0.48      0.50      0.46      2874
# weighted avg       0.73      0.84      0.77      2874
#
# Confusion matrix with 900 trees:
#  [[2418    8]
#  [ 447    1]]
# Accuracy of prediction with 900 trees: 0.842
#
# Classification report with 1300 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2426
#            1       0.33      0.01      0.01       448
#
#     accuracy                           0.84      2874
#    macro avg       0.59      0.50      0.46      2874
# weighted avg       0.76      0.84      0.77      2874
#
# Confusion matrix with 1300 trees:
#  [[2420    6]
#  [ 445    3]]
# Accuracy of prediction with 1300 trees: 0.843
#
# Classification report with 1700 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2426
#            1       0.20      0.00      0.01       448
#
#     accuracy                           0.84      2874
#    macro avg       0.52      0.50      0.46      2874
# weighted avg       0.74      0.84      0.77      2874
#
# Confusion matrix with 1700 trees:
#  [[2418    8]
#  [ 446    2]]
# Accuracy of prediction with 1700 trees: 0.842

# %% [markdown]
# ### Create a loop with increasing number of trees in the random forest (max depth 5)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

for n_tree in range(100, 2101, 400):
    rfc = RandomForestClassifier(n_estimators=n_tree, criterion='gini', max_depth=5)
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cr = classification_report(y_test,rfc_pred)
    print("Classification report with",n_tree,"trees:\n", cr)
    cm = confusion_matrix(y_test,rfc_pred)
    print("Confusion matrix with",n_tree,"trees:\n", cm)
    print ("Accuracy of prediction with",n_tree,"trees:",round((cm[0,0]+cm[1,1])/cm.sum(),3), end="\n\n")
# Out:
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification report with 100 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2423
#            1       0.00      0.00      0.00       451
#
#     accuracy                           0.84      2874
#    macro avg       0.42      0.50      0.46      2874
# weighted avg       0.71      0.84      0.77      2874
#
# Confusion matrix with 100 trees:
#  [[2423    0]
#  [ 451    0]]
# Accuracy of prediction with 100 trees: 0.843
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification report with 500 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2423
#            1       0.00      0.00      0.00       451
#
#     accuracy                           0.84      2874
#    macro avg       0.42      0.50      0.46      2874
# weighted avg       0.71      0.84      0.77      2874
#
# Confusion matrix with 500 trees:
#  [[2423    0]
#  [ 451    0]]
# Accuracy of prediction with 500 trees: 0.843
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification report with 900 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2423
#            1       0.00      0.00      0.00       451
#
#     accuracy                           0.84      2874
#    macro avg       0.42      0.50      0.46      2874
# weighted avg       0.71      0.84      0.77      2874
#
# Confusion matrix with 900 trees:
#  [[2423    0]
#  [ 451    0]]
# Accuracy of prediction with 900 trees: 0.843
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification report with 1300 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2423
#            1       0.00      0.00      0.00       451
#
#     accuracy                           0.84      2874
#    macro avg       0.42      0.50      0.46      2874
# weighted avg       0.71      0.84      0.77      2874
#
# Confusion matrix with 1300 trees:
#  [[2423    0]
#  [ 451    0]]
# Accuracy of prediction with 1300 trees: 0.843
#
# Classification report with 1700 trees:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2423
#            1       0.00      0.00      0.00       451
#
#     accuracy                           0.84      2874
#    macro avg       0.42      0.50      0.46      2874
# weighted avg       0.71      0.84      0.77      2874
#
# Confusion matrix with 1700 trees:
#  [[2423    0]
#  [ 451    0]]
# Accuracy of prediction with 1700 trees: 0.843
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/arno/Documents/FAIML/.FAIML_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
